# %% [markdown]
# # Parking Garage Project
#
# Your assignment for today is to create a parking garage class to get more familiar with Object Oriented Programming(OOP).
#
# Your parking gargage class should have the following methods:
# - takeTicket
#    - This should decrease the amount of tickets available by 1
#    - This should decrease the amount of parkingSpaces available by 1
# - payForParking
#    - Display an input that waits for an amount from the user and store it in a variable
#    - If the payment variable is not empty then ->  display a message to the user that their ticket has been paid and they have 15mins to leave
#    - This should update the "currentTicket" dictionary key "paid" to True
# -leaveGarage
#    - If the ticket has been paid, display a message of "Thank You, have a nice day"
#    - If the ticket has not been paid, display an input prompt for payment
#       - Once paid, display message "Thank you, have a nice day!"
#    - Update parkingSpaces list to increase by 1
#    - Update tickets list to increase by 1
#
# You will need a few attributes as well:
# - tickets -> list
# - parkingSpaces -> list
# - currentTicket -> dictionary

# %%
# Your Code will go here
class ParkingGarage():
    def __init__(self,currentTicket, tickets = [1,2,3,4,5], parkingSpaces = [1,2,3,4,5],):
        self.tickets = tickets
        self.parkingSpaces = parkingSpaces
        self.currentTicket = {}

    def takeTicket(self):
        if len(self.tickets) and len(self.parkingSpaces) >0 :
            self.tickets.pop()
            self.parkingSpaces.pop()
            self.currentTicket["Paid"] = False
        else:
            print("Sorry, this parking lot is full")

    def payForParking(self):
        amount = float(input("Enter your payment please: "))
        if amount >= 5:
            print("Ticket has been paid. You have 15 minutes to leave.")
            self.currentTicket["Paid"] = True
        else:
            print("Insufficient amount. Please check your ticket and update your payment.")

    def leaveGarage(self):
        if self.currentTicket.get("Paid", True):
            print("Thank you, have a great day!")
            self.tickets.append(1)
            self.parkingSpaces.append(1)
            self.currentTicket["Paid"] = True
        else:
            print("Please enter correct payment.")
def run ():
  pass
  #create a run statement to only execute if the amount of spaces and tickets
  #availble is less than the amount of spaces and tickets available
# Out:
# Sorry, this parking lot is full
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-14da03c6b2ac> in <cell line: 40>()
#      38
#      39 garage.takeTicket()
# ---> 40 garage.payForParking()
#      41 garage.leaveGarage()
#
# <ipython-input-4-14da03c6b2ac> in payForParking(self)
#      15
#      16     def payForParking(self):
# ---> 17         amount = float(input("Enter your payment please: "))
#      18         if amount >= 5:
#      19             print("Ticket has been paid. You have 15 minutes to leave.")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
